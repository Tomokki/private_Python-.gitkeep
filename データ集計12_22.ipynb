# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomokki/private_Python-.gitkeep/blob/main/%E3%83%87%E3%83%BC%E3%82%BF%E9%9B%86%E8%A8%8812_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("fruits.csv")

# %%
print(df)
# Out:
#    fruits country  price  quantity
# 0   apple      US    100         5
# 1  orange   Japan    150         4
# 2  orange   Japan    200         3
# 3  orange   Japan    150         2
# 4   apple   Japan    300         1
# 5   apple      US    100         9
# 6   apple      US    200        10

# %%
print(df.groupby("fruits").size())
# Out:
# fruits
# apple     4
# orange    3
# dtype: int64

# %%
print(df.groupby("fruits").mean())
# Out:
#              price  quantity
# fruits
# apple   175.000000      6.25
# orange  166.666667      3.00
# <ipython-input-43-e4e72f4daad0>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(df.groupby("fruits").mean())

# %%
print(df.groupby("fruits").sum())
# Out:
#         price  quantity
# fruits
# apple     700        25
# orange    500         9
# <ipython-input-44-da6b34d0ecd1>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(df.groupby("fruits").sum())

# %%
print(df.groupby(["fruits","country"]).sum())
# Out:
#                 price  quantity
# fruits country
# apple  Japan      300         1
#        US         400        24
# orange Japan      500         9

# %%
df = pd.read_csv("fruits.csv")

# %%
print(df)
# Out:
#    fruits country  price  quantity
# 0   apple      US    100         5
# 1  orange   Japan    150         4
# 2  orange   Japan    200         3
# 3  orange   Japan    150         2
# 4   apple   Japan    300         1
# 5   apple      US    100         9
# 6   apple      US    200        10

# %%
print(pd.crosstab(df["fruits"],df["country"]))
# Out:
# country  Japan  US
# fruits
# apple        1   3
# orange       3   0

# %%
print(pd.crosstab(df["fruits"],df["country"],margins=True))
# Out:
# country  Japan  US  All
# fruits
# apple        1   3    4
# orange       3   0    3
# All          4   3    7

# %%
print(pd.crosstab(df["fruits"],df["country"],margins=True,normalize="index"))
# Out:
# country     Japan        US
# fruits
# apple    0.250000  0.750000
# orange   1.000000  0.000000
# All      0.571429  0.428571

# %%
print(pd.crosstab(df["fruits"],df["country"],margins=True,normalize=True))
# Out:
# country     Japan        US       All
# fruits
# apple    0.142857  0.428571  0.571429
# orange   0.428571  0.000000  0.428571
# All      0.571429  0.428571  1.000000

# %%
print(pd.crosstab(df["fruits"],df["country"],margins=True,normalize="columns"))
# Out:
# country  Japan   US       All
# fruits
# apple     0.25  1.0  0.571429
# orange    0.75  0.0  0.428571

# %%
df = pd.read_csv("fruits.csv")

# %%
print(df)
# Out:
#    fruits country  price  quantity
# 0   apple      US    100         5
# 1  orange   Japan    150         4
# 2  orange   Japan    200         3
# 3  orange   Japan    150         2
# 4   apple   Japan    300         1
# 5   apple      US    100         9
# 6   apple      US    200        10

# %%
print(pd.pivot_table(df,index="fruits",columns="country",values="price",aggfunc="sum"))
# Out:
# country  Japan     US
# fruits
# apple    300.0  400.0
# orange   500.0    NaN

# %%
print(pd.pivot_table(df,index="fruits",columns="country",values="price",aggfunc="size"))
# Out:
# country  Japan   US
# fruits
# apple      1.0  3.0
# orange     3.0  NaN

# %%
# !pip install numpy
import numpy as np

# %%
print(pd.pivot_table(df,index="fruits",columns="country",values="price",aggfunc=np.min))
# Out:
# country  Japan     US
# fruits
# apple    300.0  100.0
# orange   150.0    NaN

# %%
print(pd.pivot_table(df,index="fruits",columns="country",values="price"))
# Out:
# country       Japan          US
# fruits
# apple    300.000000  133.333333
# orange   166.666667         NaN

# %% [markdown]
# ####練習問題①
# 4種類のデータそれぞれ読み込んで先頭５行のみ表示しなさい

# %%
import pandas as pd
#customer_master.csv
customer_master = pd.read_csv("customer_master.csv")
customer_master.head
# Out:
# <bound method NDFrame.head of      customer_id customer_name    registration_date customer_name_kana  \
# 0       IK152942        平田 裕次郎  2019-01-01 00:25:33          ひらた ゆうじろう
# 1       TS808488         田村 詩織  2019-01-01 01:13:45            たむら しおり
# 2       AS834628         久野 由樹  2019-01-01 02:00:14             ひさの ゆき
# 3       AS345469          鶴岡 薫  2019-01-01 04:48:22           つるおか かおる
# 4       GD892565         大内 高史  2019-01-01 04:54:51           おおうち たかし
# ...          ...           ...                  ...                ...
# 4995    AS677229         平山 莉沙  2019-07-31 16:52:26            ひらやま りさ
# 4996    HD758694        中原 まひる  2019-07-31 19:09:26           なかはら まひる
# 4997    PL538517         田端 由宇  2019-07-31 19:30:05             たばた ゆう
# 4998    OA955088         瀬戸内 光  2019-07-31 22:32:08           せとうち ひかる
# 4999    HI349563         堀井 寛治  2019-07-31 22:49:49            ほりい かんじ
#
#                             email gender  age       birth pref
# ...

# %%
#item_master.csv
item_master = pd.read_csv("item_master.csv")
item_master.head
# Out:
# <bound method NDFrame.head of   item_id item_name  item_price
# 0    S001      PC-A       50000
# 1    S002      PC-B       85000
# 2    S003      PC-C      120000
# 3    S004      PC-D      180000
# 4    S005      PC-E      210000>

# %%
#transaction_1.csv
transaction_1 = pd.read_csv("transaction_1.csv")
transaction_1.head()
# Out:
#   transaction_id   price         payment_date customer_id
# 0    T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1    T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2    T0000000115  120000  2019-02-01 02:34:19    HD298120
# 3    T0000000116  210000  2019-02-01 02:47:23    IK452215
# 4    T0000000117  170000  2019-02-01 04:33:46    PL542865

# %%
#transaction_detail_1.csv
transaction_detail_1 = pd.read_csv("transaction_detail_1.csv")
transaction_detail_1.head()
# Out:
#    detail_id transaction_id item_id  quantity
# 0          0    T0000000113    S005         1
# 1          1    T0000000114    S001         1
# 2          2    T0000000115    S003         1
# 3          3    T0000000116    S005         1
# 4          4    T0000000117    S002         2

# %% [markdown]
# ####練習問題②
# 4種類のデータの概要を説明しなさい

# %%
#customer_master:名前、mail、年齢、詳細情報
#item_master:商品名、価格
#transaction_1:いくらのものをいつ購入したか
#transaction_detail_1:購入商品や数量

# %% [markdown]
# ###データの結合
# ２つのファイルを縦に結合⇒Union
#
# ２つのファイルを横に結合⇒Join

# %% [markdown]
# ####練習問題④  データ結合Union
# transaction_1 と transaction_2 の Union を行い、
# transaction
# というデータフレーム型の変数に格納しなさい。
# transaction の先頭 5 行を出力しなさい
# transaction_1 と transaction_2 と transaction の行数を出力
# しなさい
# transaction_detail_1 と transaction_detail_2 についても同様の
# 処理を行いなさい

# %%
#concat 関数を用いて複数の DataFrame を連結可能

# a = pd.read_csv("sales_2020.csv")
# a["date"] = a["date"].apply(pd.to_datetime)

# b = pd.read_csv("sales_2015.csv")
# b["date"] = b["date"].apply(pd.to_datetime)


# axis=0 で列方向（下）に連結
# c = pd.concat([b,a],axis=0)
# print(c)

# axis=1 で行方向（右）に連結
# d = pd.concat([b,a],axis=1)
# print(d)

# %% [markdown]
# concat 関数のオプションは以下の通り
#
# join="outer"
# 全てのラベルを残す（デフォルト）
# join="inner"
# 両方に共通するラベルのみ残す
# join_axes="
# ラベル名 指定したラベルを残す

# %%
# 練習問題④answer

# transaction_1とtransaction_2 のUnion を行い、transactionというデータフレーム型の変数に格納しなさい。
# transaction の先頭 5 行を出力しなさい

transaction_2 = pd.read_csv("transaction_2.csv")
transaction = pd.concat([transaction_1,transaction_2],ignore_index=True)
transaction.head()
# Out:
#   transaction_id   price         payment_date customer_id
# 0    T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1    T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2    T0000000115  120000  2019-02-01 02:34:19    HD298120
# 3    T0000000116  210000  2019-02-01 02:47:23    IK452215
# 4    T0000000117  170000  2019-02-01 04:33:46    PL542865

# %%
# 練習問題④answer

# transaction_1 と transaction_2 と transaction の行数を出力しなさい

print(len(transaction_1))
print(len(transaction_2))
print(len(transaction))
# Out:
# 5000
# 1786
# 6786

# %%
# 練習問題④answer

# transaction_detail_1 と transaction_detail_2 についても同様の処理を行いなさい

transaction_detail_2 = pd.read_csv("transaction_detail_2.csv")
transaction_detail = pd.concat([transaction_detail_1,transaction_detail_2],ignore_index=True)
transaction_detail.head()
# Out:
#    detail_id transaction_id item_id  quantity
# 0          0    T0000000113    S005         1
# 1          1    T0000000114    S001         1
# 2          2    T0000000115    S003         1
# 3          3    T0000000116    S005         1
# 4          4    T0000000117    S002         2

# %%
#行数の出力
print(len(transaction_detail_1))
print(len(transaction_detail_2))
print(len(transaction_detail))
# Out:
# 5000
# 2144
# 7144

# %% [markdown]
# ####練習問題⑤
# 1.transaction_detail に足りない（付加したい）データ列は何か？
#
# →payment_date 、 customer_id
# →transaction の price は、一回の購買データごとの合計金額であり、transaction_detail の quantity と item_master の item_priceから算出される
# →transaction_detail の方がデータの粒度が細かいため、付加してし
# まうと、二重計上になってしまうので price を付加してはならない
#
# 2.2つのファイルに共通するデータ列は何か？
# →transaction_id

# %%
# □transaction_detail と transaction の Join を行い、 join_dataというデータフレーム型の変数に格納しなさい。
join_data = pd.merge(transaction_detail,transaction[["transaction_id","payment_date","customer_id"]],on="transaction_id",how="left")
# join_data の先頭 5 行を出力しなさい
join_data.head()
# Out:
#    detail_id transaction_id item_id  quantity         payment_date customer_id
# 0          0    T0000000113    S005         1  2019-02-01 01:36:57    PL563502
# 1          1    T0000000114    S001         1  2019-02-01 01:37:23    HD678019
# 2          2    T0000000115    S003         1  2019-02-01 02:34:19    HD298120
# 3          3    T0000000116    S005         1  2019-02-01 02:47:23    IK452215
# 4          4    T0000000117    S002         2  2019-02-01 04:33:46    PL542865

# %%
# transaction_detail と transaction と join_data の行数を出力しなさい
print(len(transaction_detail))
print(len(transaction))
print(len(join_data))

# transaction_detail と join_data は同じ件数となっており、
# 縦にデータが増えたのではなく、横にデータが増えており、
# ジョインできていることが確認できる
# Out:
# 7144
# 6786
# 7144

# %% [markdown]
# ####練習問題⑦：データ結合（Join）
# join_data と customer_master の Join を行い、 join_data と
# いうデータフレーム型の変数に格納しなさい。
# join_data と item_master の Join を行い、 join_data というデー
# タフレーム型の変数に格納しなさい。
# join_data の先頭 5 行を出力しなさい

# %%
join_data = pd.merge(join_data,customer_master,on="customer_id",how="left")
join_data = pd.merge(join_data,item_master, on="item_id",how="left")
join_data.head()
# Out:
#    detail_id transaction_id item_id  quantity         payment_date  \
# 0          0    T0000000113    S005         1  2019-02-01 01:36:57
# 1          1    T0000000114    S001         1  2019-02-01 01:37:23
# 2          2    T0000000115    S003         1  2019-02-01 02:34:19
# 3          3    T0000000116    S005         1  2019-02-01 02:47:23
# 4          4    T0000000117    S002         2  2019-02-01 04:33:46
#
#   customer_id customer_name    registration_date customer_name_kana  \
# 0    PL563502         井本 芳正  2019-01-07 14:34:35           いもと よしまさ
# 1    HD678019         三船 六郎  2019-01-27 18:00:11           みふね ろくろう
# 2    HD298120         山根 小雁  2019-01-11 08:16:02            やまね こがん
# 3    IK452215         池田 菜摘  2019-01-10 05:07:38            いけだ なつみ
# 4    PL542865         栗田 憲一  2019-01-25 06:46:05           くりた けんいち
#
#                          email gender  age       birth pref item_name  \
# 0  imoto_yoshimasa@example.com      M   30   1989/7/15  熊本県      PC-E
# ...

# %% [markdown]
# ####練習問題⑧：必要データ列の作成
# quantity と item_price の 掛け算を計算し、新規に作成した price
# 列に格納しなさい
# quantity 、 item_price 、 price 列の先頭 5 行を出力しなさい

# %%
join_data["price"] = join_data["quantity"] * join_data["item_price"]
join_data[["quantity","item_price","price"]].head()
# Out:
#    quantity  item_price   price
# 0         1      210000  210000
# 1         1       50000   50000
# 2         1      120000  120000
# 3         1      210000  210000
# 4         2       85000  170000

# %% [markdown]
# ####練習問題⑨：加工後のデータ列の検算
# データ加工前の transaction データにおける price と、データ加工後に
# 計算によって作成した price 列は合計すると同じ値になるはずである
# price 合計の値を確認し、同じ値になることを示しなさい
# price 合計の値を比較し、同じ値である場合は True を出力しなさい

# %%
print(join_data["price"].sum())
print(transaction["price"].sum())
# Out:
# 971135000
# 971135000

# %%
join_data["price"].sum()== transaction["price"].sum()
# Out:
# True

# %% [markdown]
# ###データ分析上での２つの数字
# 1.欠損している値の状況
# 欠損値は実際のほとんどのデータに含まれている
# 欠損値は集計や機械学習に大きく影響するため、データクレンジングが必要
# データクレンジングの規模を把握するために、欠損値の数を把握する
# 2.データ全体の傾向
# データ分析では、商品毎、顧客属性毎など、さまざまな切り口で集計を行う
# その際に、今月の商品 A が 10 万円だったとわかったとしても、全体の売上が 10億円単位規模なのか 100 万円規模なのかによって意味が大きく異なる
# そこで、全体の数字感を掴むのが重要となる

# %% [markdown]
# ####練習問題⑩：欠損値の数の確認
# 欠損値の数を表示しなさい

# %%
join_data.isnull().sum()
# Out:
# detail_id             0
# transaction_id        0
# item_id               0
# quantity              0
# payment_date          0
# customer_id           0
# customer_name         0
# registration_date     0
# customer_name_kana    0
# email                 0
# gender                0
# age                   0
# birth                 0
# pref                  0
# item_name             0
# item_price            0
# price                 0
# dtype: int64

# %% [markdown]
# ####練習問題⑪：基本統計量の確認
# 基本統計量を表示しなさい
# データの期間範囲を表示しなさい

# %%
join_data.describe()
# Out:
#          detail_id     quantity          age     item_price          price
# count  7144.000000  7144.000000  7144.000000    7144.000000    7144.000000
# mean   3571.500000     1.199888    50.265677  121698.628219  135937.150056
# std    2062.439494     0.513647    17.190314   64571.311830   68511.453297
# min       0.000000     1.000000    20.000000   50000.000000   50000.000000
# 25%    1785.750000     1.000000    36.000000   50000.000000   85000.000000
# 50%    3571.500000     1.000000    50.000000  102500.000000  120000.000000
# 75%    5357.250000     1.000000    65.000000  187500.000000  210000.000000
# max    7143.000000     4.000000    80.000000  210000.000000  420000.000000

# %% [markdown]
# #####price を見ると、平均は 135937 円となっている。最高金額は420000 円となっており、これは単価 210000 円の PC を 2 台買ったユーザーがいると想像できる
# #####quantity を見ると、最高は 4 だが、 75% 数でも 1 なので、ほとんどの顧客が数量 1 で購入していることがわかる。さらに、 age を見ると、 20 歳から 80 歳までの範囲の顧客像が見えてくる

# %%
# データの期間範囲を表示しなさい
print(join_data["payment_date"].min())
print(join_data["payment_date"].max())
# Out:
# 2019-02-01 01:36:57
# 2019-07-31 23:41:38

# %% [markdown]
# ###月別のデータ集計
# データに日時が含まれる場合は、時系列でデータを確認すると良い
# 今回のように、半年程度のデータであれば影響は出ることはあまりないが、過去数年のデータ等を扱うとなると、ビジネスモデルの変化等により一纏めに分析すると見誤るケースがため、データ範囲を絞ることもある
# 全体的に売上が伸びているのか、落ちているのかを把握するのは、分析の第一歩と言える
# まずは、月別に集計して一覧表示してみましょう。

# %% [markdown]
# #####練習問題⑫：データ型を確認
# join_data の中で日付に該当する列を示しなさい
# join_data の各列のデータ型を確認しなさい
# join_data の中で日付に該当する列の型を示しなさい

# %%
join_data.dtypes
# 各列のデータ型の確認

# join_data の中で日付に該当する列を示しなさい⇒payment_date
# join_data の中で日付に該当する列の型を示しなさい⇒object
# Out:
# detail_id              int64
# transaction_id        object
# item_id               object
# quantity               int64
# payment_date          object
# customer_id           object
# customer_name         object
# registration_date     object
# customer_name_kana    object
# email                 object
# gender                object
# age                    int64
# birth                 object
# pref                  object
# item_name             object
# item_price             int64
# price                  int64
# dtype: object

# %% [markdown]
# #####練習問題⑬：型変換
# payment_date を object 型 から datetime 型 に変換しなさい
# payment_date から年月の情報を抽出し、新たに作成したpayment_month 列に格納しなさい
# payment_date と payment_month の先頭 5 行を出力しなさい

# %%
join_data["payment_date"] = pd.to_datetime(join_data["payment_date"])
join_data["payment_month"] = join_data["payment_date"].dt.strftime("%Y%m")
join_data[["payment_date","payment_month"]].head()
# Out:
#          payment_date payment_month
# 0 2019-02-01 01:36:57        201902
# 1 2019-02-01 01:37:23        201902
# 2 2019-02-01 02:34:19        201902
# 3 2019-02-01 02:47:23        201902
# 4 2019-02-01 04:33:46        201902

# %% [markdown]
# #####練習問題⑭：月別売上の集計
# 月ごとにデータを集計しなさい

# %%
join_data.groupby("payment_month").sum()
# Out:
# <ipython-input-86-47dbb15c38fa>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   join_data.groupby("payment_month").sum()
#                detail_id  quantity    age  item_price      price
# payment_month
# 201902            676866      1403  59279   142805000  160185000
# 201903           2071474      1427  58996   142980000  160370000
# 201904           3476816      1421  59246   143670000  160510000
# 201905           4812795      1390  58195   139655000  155420000
# 201906           6369999      1446  61070   147090000  164030000
# 201907           8106846      1485  62312   153215000  170620000

# %% [markdown]
# #####練習問題⑮：月別、商品別売上の集計
# 月別、商品別にデータを集計しなさい
# ピボットテーブルを用いて行を商品別、列を月別とたクロス集計表を作成しなさい

# %%
join_data.groupby(["payment_month","item_name"]).sum()[["price","quantity"]]
# 月別、商品別
# Out:
# <ipython-input-87-ca499f2db8a7>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   join_data.groupby(["payment_month","item_name"]).sum()[["price","quantity"]]
#                             price  quantity
# payment_month item_name
# 201902        PC-A       24150000       483
#               PC-B       25245000       297
#               PC-C       19800000       165
#               PC-D       31140000       173
#               PC-E       59850000       285
# 201903        PC-A       26000000       520
#               PC-B       25500000       300
#               PC-C       19080000       159
#               PC-D       25740000       143
#               PC-E       64050000       305
# 201904        PC-A       25900000       518
#               PC-B       23460000       276
# ...

# %%
pd.pivot_table(join_data, index="item_name",columns="payment_month",values=["price","quantity"],aggfunc="sum")

# クロス集計
# Out:
#                   price                                                    \
# payment_month    201902    201903    201904    201905    201906    201907
# item_name
# PC-A           24150000  26000000  25900000  24850000  26000000  25250000
# PC-B           25245000  25500000  23460000  25330000  23970000  28220000
# PC-C           19800000  19080000  21960000  20520000  21840000  19440000
# PC-D           31140000  25740000  24300000  25920000  28800000  26100000
# PC-E           59850000  64050000  64890000  58800000  63420000  71610000
#
#               quantity
# payment_month   201902 201903 201904 201905 201906 201907
# item_name
# PC-A               483    520    518    497    520    505
# PC-B               297    300    276    298    282    332
# PC-C               165    159    183    171    182    162
# PC-D               173    143    135    144    160    145
# PC-E               285    305    309    280    302    341

# %%
# 考察
# 最も高価格の PC E が、各月の売上の合計値が最も高い
# 最も低価格の PC A が、各月の数量が最も多い
# 月別推移では 5 月の売上が低下し、 6 月、 7 月で増加
# 5 月は PC B 、 PC D は増加していますが、大きな売上を占める PC E の売上が大きく低下している
# 6 月、 7 月は、 PC E が大きく伸びている

# %%
# 集計結果の可視化
# 表形式のデータは、細かい数字が把握できる一方で、伸びているのか、落ちているのかが一目ではわからない
# 分析のゴールはあくまでも現場で適切に運用され施策を回していくことである
# お客さんや現場の人の中には、数字が苦手な方もいるので、いかにして伝えるかはとても重要である
# 月別、商品別の売上推移をグラフで可視化

# %% [markdown]
# #####練習問題⑯：商品別の売上推移の可視化
# ピボットテーブルを用いて payment_month を index 、item_name を columns としたクロス集計表を作成しなさい
# 上記のクロス集計表を折れ線グラフで可視化しなさい

# %%
graph_data = pd.pivot_table(join_data, index="payment_month",columns="item_name",values="price",aggfunc="sum")
graph_data.head()
# Out:
# item_name          PC-A      PC-B      PC-C      PC-D      PC-E
# payment_month
# 201902         24150000  25245000  19800000  31140000  59850000
# 201903         26000000  25500000  19080000  25740000  64050000
# 201904         25900000  23460000  21960000  24300000  64890000
# 201905         24850000  25330000  20520000  25920000  58800000
# 201906         26000000  23970000  21840000  28800000  63420000

# %%
import matplotlib.pyplot as plt
import matplotlib.style

matplotlib.style.use("ggplot")
plt.plot(list(graph_data.index),graph_data["PC-A"],label="PC-A")
plt.plot(list(graph_data.index),graph_data["PC-B"],label="PC-B")
plt.plot(list(graph_data.index),graph_data["PC-C"],label="PC-C")
plt.plot(list(graph_data.index),graph_data["PC-D"],label="PC-D")
plt.plot(list(graph_data.index),graph_data["PC-E"],label="PC-E")
plt.legend()
